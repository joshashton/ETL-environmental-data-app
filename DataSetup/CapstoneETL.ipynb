# %%
#imports 
import requests
from pprint import pprint
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import os
import warnings
# Suppress FutureWarning messages
warnings.simplefilter(action='ignore', category=FutureWarning)

import difflib 

#database connection
import psycopg2 as psql 
from dotenv import load_dotenv
import os
import base64
import pprint

from statistics import mean
import datetime

# %%
#get secrets from .env
load_dotenv()

api_key = os.getenv('API_KEY')
NASA_api_key = os.getenv('NASA_API_KEY')
METEOSTAT_api_key = os.getenv('METEOSTAT_API_KEY')

# %% [markdown]
# ### Connect to API

# %% [markdown]
# ### Nasa

# %% [markdown]
# #### Different api stuff to add

# %% [markdown]
# Climate
# * weather - open-meteo
# * NASA natural disasters - https://eonet.gsfc.nasa.gov/api/v2.1/events ?days=20
#
#
# Space Objects
# * NEO - https://api.nasa.gov/neo/rest/v1/neo/3542519?api_key=DEMO_KEY
# * JPL’s SSD (Solar System Dynamics) and CNEOS (Center for Near-Earth Object Studies) - https://ssd-api.jpl.nasa.gov/
#
#
# Space Pictures
# * picture of the day - https://api.nasa.gov/planetary/apod?api_key=DEMO_KEY&count=5
# * mars photo api - https://api.nasa.gov/mars-photos/
# * earth picture - https://epic.gsfc.nasa.gov/

# %% [markdown]
# ### Climate

# %% [markdown]
# #### Weather

# %%
df = pd.read_csv('Data/weather.csv')
df

# %%
df
# Out:
#              country capital        date  season  avg_temp_c  min_temp_c  \
# 0        Afghanistan   Kabul  1966-03-02  winter         7.1         NaN
# 1        Afghanistan   Kabul  1966-03-28  spring         7.9         NaN
# 2        Afghanistan   Kabul  1966-05-02  spring        18.8         NaN
# 3        Afghanistan   Kabul  1966-05-04  spring        19.7         NaN
# 4        Afghanistan   Kabul  1966-05-18  spring        24.6         NaN
# ...              ...     ...         ...     ...         ...         ...
# 5002446     Zimbabwe  Harare  2023-08-15  winter        20.1        11.0
# 5002447     Zimbabwe  Harare  2023-08-16  winter        18.6        12.4
# 5002448     Zimbabwe  Harare  2023-08-17  winter        17.5        10.7
# 5002449     Zimbabwe  Harare  2023-08-18  winter        18.9        10.1
# 5002450     Zimbabwe  Harare  2023-08-19  winter        21.1        12.4
#
#          max_temp_c  precipitation_mm  snow_depth_mm  avg_wind_dir_deg  \
# 0               NaN               NaN            NaN               NaN
# 1               NaN               NaN            NaN               NaN
# 2              22.2               NaN            NaN               NaN
# 3              27.2               NaN            NaN               NaN
# 4               NaN               NaN            NaN               NaN
# ...             ...               ...            ...               ...
# 5002446        28.1               0.0            NaN             120.0
# 5002447        25.6               0.0            NaN             116.0
# 5002448        24.7               0.0            NaN              94.0
# 5002449        27.2               0.0            NaN              56.0
# 5002450        29.4               0.0            NaN              90.0
#
#          avg_wind_speed_kmh  peak_wind_gust_kmh  avg_sea_level_pres_hpa  \
# 0                       NaN                 NaN                     NaN
# 1                       NaN                 NaN                     NaN
# 2                       NaN                 NaN                     NaN
# 3                       NaN                 NaN                     NaN
# 4                       NaN                 NaN                     NaN
# ...                     ...                 ...                     ...
# 5002446                 8.5                 NaN                  1018.5
# 5002447                17.4                 NaN                  1021.2
# 5002448                14.3                 NaN                  1020.9
# 5002449                 9.1                 NaN                  1018.2
# 5002450                11.3                 NaN                  1016.9
#
#          sunshine_total_min
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 5002446                 NaN
# 5002447                 NaN
# 5002448                 NaN
# 5002449                 NaN
# 5002450                 NaN
#
# [5002451 rows x 14 columns]

# %% [markdown]
# ##### Set up DB Data

# %%
# populate db with past data first
#df = pd.read_parquet('Data/daily_weather.parquet')
df = pd.read_csv('Data/weather.csv')

#remove columns
weather_df = df[['country', 'capital', 'date', 'avg_temp_c', 'precipitation_mm','avg_wind_speed_kmh']]

#add long and lats for each city
countries_df = pd.read_csv('Data/country-capital-lat-long-population.csv')
countries_df = countries_df[['Country','Latitude', 'Longitude']]
countries_df.rename(columns={'Country': 'country', 'Latitude' : 'latitude', 'Longitude' : 'longitude'}, inplace=True)

#add mssing lat long manually
data = {
    'country': ['Bolivia','British Indian Ocean Territory', 'Brunei', 'Cape Verde',
       'Christmas Island', 'Cocos (Keeling) Islands', 'Czech Republic',
       'East Timor', 'Falkland Islands', 'Faroe Islands',
       'Federated States of Micronesia',
       'French Southern and Antarctic Lands', 'Guernsey', 'Hong Kong',
       'Iran', 'Ivory Coast', 'Jersey', 'Laos', 'Macedonia', 'Moldova',
       'Norfolk Island', 'North Korea', 'Pitcairn Islands',
       'Republic of the Congo', 'Russia', 'South Georgia', 'South Korea',
       'Svalbard and Jan Mayen', 'Syria', 'São Tomé and Príncipe',
       'Taiwan', 'Tanzania', 'The Bahamas', 'The Gambia', 'United States',
       'Venezuela', 'Vietnam', 'Wallis and Futuna'],
    'latitude': [-16.5000, -7.3195, 4.8903, 14.9167, -10.4167, -12.1167, 50.0833,
       -8.5594, -51.7000, 62.0167, 6.9167, -49.3500, 49.4500, 22.2783,
       35.6944, 6.8167, 49.1833, 17.9667, 42.0000, 47.0056, -29.0569,
       39.0194, -25.0667, -4.2592, 55.7558, -54.2833, 37.5665, 78.2333,
       33.5000, 0.3333, 25.0330, -6.8000, 25.0833, 13.4531, 38.8951,
       10.4806, 21.0285, -13.2833],
    'longitude': [-68.1500, 72.4229, 114.9403, -23.5167, 105.7167, 96.9000, 14.4167,
       125.5795, -57.8500, -6.7667, 158.1500, 70.2167, -2.5333, 114.1747,
       51.4215, -5.2667, -2.1000, 102.6000, 21.4333, 28.8575, 167.9597,
       125.7547, -130.1000, 15.2847, 37.6173, -36.5000, 126.9780, 15.6333,
       36.3000, 6.7333, 121.5654, 39.2833, -77.3500, -16.5775, -77.0364,
       -66.9036, 105.8542, -176.1667]
}
data_df = pd.DataFrame(data)
countries_df = pd.concat([countries_df, data_df], ignore_index=True)

merged_df = weather_df.merge(countries_df, on='country', how='left')
merged_df.tail()
# Out:
#           country capital        date  avg_temp_c  precipitation_mm  \
# 5002446  Zimbabwe  Harare  2023-08-15        20.1               0.0
# 5002447  Zimbabwe  Harare  2023-08-16        18.6               0.0
# 5002448  Zimbabwe  Harare  2023-08-17        17.5               0.0
# 5002449  Zimbabwe  Harare  2023-08-18        18.9               0.0
# 5002450  Zimbabwe  Harare  2023-08-19        21.1               0.0
#
#          avg_wind_speed_kmh  latitude  longitude
# 5002446                 8.5  -17.8294    31.0539
# 5002447                17.4  -17.8294    31.0539
# 5002448                14.3  -17.8294    31.0539
# 5002449                 9.1  -17.8294    31.0539
# 5002450                11.3  -17.8294    31.0539

# %%
#Fill rest of dates for weather from API +2023-08-20
def process_json_response(jsonRes, latitude, longitude):
    data_list = []
    
    for day_data in jsonRes['data']:
        data = {
            'date': day_data['date'],
            'avg_temp_c': day_data['tavg'],
            'precipitation_mm': day_data['prcp'],
            'avg_wind_speed_kmh': day_data['wspd'],
            'latitude': latitude,
            'longitude': longitude
        }
        data_list.append(data)
    
    return pd.DataFrame(data_list)


def get_weather_data(lat, lon):
    url = "https://meteostat.p.rapidapi.com/point/daily"
    querystring = {"lat":str(lat),"lon":str(lon),"start":"2023-08-20","end":"2024-06-26"}
    headers = {
        "x-rapidapi-key": METEOSTAT_api_key,
        "x-rapidapi-host": "meteostat.p.rapidapi.com"
    }
    response = requests.get(url, headers=headers, params=querystring)
    return response.json()

# Get unique pairs of latitude and longitude
coord_pairs = merged_df[['latitude', 'longitude']].drop_duplicates().values

# List to store DataFrames for each coordinate pair
df_list = []

# Loop through each coordinate pair
for lat, lon in coord_pairs:
    print(f"Fetching data for coordinates: {lat}, {lon}")
    
    try:
        # Make API call
        jsonRes = get_weather_data(lat, lon)
        
        # Process the response
        df = process_json_response(jsonRes, lat, lon)
        
        # Add to the list of DataFrames
        df_list.append(df)
        
    except Exception as e:
        print(f"Error fetching data for coordinates {lat}, {lon}: {str(e)}")

# Combine all DataFrames
combined_df = pd.concat(df_list, ignore_index=True)
combined_df = pd.DataFrame(combined_df)
# Display the resulting DataFrame
print(combined_df)
# Out:
# Fetching data for coordinates: 34.5289, 69.1725
# Fetching data for coordinates: 41.3275, 19.8189
# Fetching data for coordinates: 36.7525, 3.042
# Fetching data for coordinates: -14.2781, -170.7025
# Fetching data for coordinates: -8.8368, 13.2343
# Fetching data for coordinates: 18.217, -63.0578
# Fetching data for coordinates: 17.1172, -61.8457
# Fetching data for coordinates: -34.6051, -58.4004
# Fetching data for coordinates: 40.182, 44.5146
# Fetching data for coordinates: 12.524, -70.027
# Fetching data for coordinates: -35.2835, 149.1281
# Fetching data for coordinates: 48.2064, 16.3707
# Fetching data for coordinates: 40.3777, 49.892
# Fetching data for coordinates: 26.2154, 50.5832
# Fetching data for coordinates: 23.7104, 90.4074
# Fetching data for coordinates: 13.1, -59.6167
# Fetching data for coordinates: 53.9, 27.5667
# Fetching data for coordinates: 50.8467, 4.3499
# Fetching data for coordinates: 17.25, -88.7667
# Fetching data for coordinates: 6.3654, 2.4183
# Fetching data for coordinates: 32.2915, -64.778
# Fetching data for coordinates: 27.4661, 89.6419
# Fetching data for coordinates: -16.5, -68.15
# Fetching data for coordinates: 43.8486, 18.3564
# Fetching data for coordinates: -24.6545, 25.9086
# Fetching data for coordinates: -15.7797, -47.9297
# Fetching data for coordinates: -7.3195, 72.4229
# Fetching data for coordinates: 4.8903, 114.9403
# Fetching data for coordinates: 42.6975, 23.3242
# Fetching data for coordinates: 12.3642, -1.5383
# Fetching data for coordinates: -3.3822, 29.3644
# Fetching data for coordinates: 11.5625, 104.916
# Fetching data for coordinates: 3.8667, 11.5167
# Fetching data for coordinates: 45.4166, -75.698
# Fetching data for coordinates: 14.9167, -23.5167
# Fetching data for coordinates: 19.2866, -81.3744
# Fetching data for coordinates: 4.3612, 18.555
# Fetching data for coordinates: 12.1067, 15.0444
# Fetching data for coordinates: -33.4569, -70.6483
# Fetching data for coordinates: 39.9075, 116.3972
# Fetching data for coordinates: -10.4167, 105.7167
# Fetching data for coordinates: -12.1167, 96.9
# Fetching data for coordinates: 4.6097, -74.0818
# Fetching data for coordinates: -11.7022, 43.2551
# Fetching data for coordinates: -21.23, -159.76
# Fetching data for coordinates: 9.9278, -84.0807
# Fetching data for coordinates: 45.8144, 15.978
# Fetching data for coordinates: 23.1195, -82.3785
# Fetching data for coordinates: 35.1595, 33.3669
# Fetching data for coordinates: 50.0833, 14.4167
# Fetching data for coordinates: -4.3276, 15.3136
# Fetching data for coordinates: 55.6759, 12.5655
# Fetching data for coordinates: 11.5877, 43.1447
# Fetching data for coordinates: 15.3017, -61.3881
# Fetching data for coordinates: 18.4896, -69.9018
# Fetching data for coordinates: -8.5594, 125.5795
# Fetching data for coordinates: -0.2299, -78.525
# Fetching data for coordinates: 30.0392, 31.2394
# Fetching data for coordinates: 13.6894, -89.1872
# Fetching data for coordinates: 3.75, 8.7833
# Fetching data for coordinates: 15.3333, 38.9333
# Fetching data for coordinates: 59.437, 24.7535
# Fetching data for coordinates: 9.025, 38.7469
# Fetching data for coordinates: -51.7, -57.85
# Fetching data for coordinates: 62.0167, -6.7667
# Fetching data for coordinates: 6.9167, 158.15
# Fetching data for coordinates: -18.1416, 178.4415
# Fetching data for coordinates: 60.1692, 24.9402
# Fetching data for coordinates: 48.8534, 2.3488
# Fetching data for coordinates: 4.9333, -52.3333
# Fetching data for coordinates: -17.5333, -149.5667
# Fetching data for coordinates: -49.35, 70.2167
# Fetching data for coordinates: 0.3925, 9.4537
# Fetching data for coordinates: 41.6941, 44.8337
# Fetching data for coordinates: 52.5244, 13.4105
# Fetching data for coordinates: 5.556, -0.1969
# Fetching data for coordinates: 36.1447, -5.3526
# Fetching data for coordinates: 37.9534, 23.749
# Fetching data for coordinates: 64.1835, -51.7216
# Fetching data for coordinates: 12.0564, -61.7485
# Fetching data for coordinates: 15.9985, -61.7255
# Fetching data for coordinates: 13.4757, 144.7489
# Fetching data for coordinates: 14.6127, -90.5307
# Fetching data for coordinates: 49.45, -2.5333
# Fetching data for coordinates: 9.5716, -13.6476
# Fetching data for coordinates: 11.8636, -15.5977
# Fetching data for coordinates: 6.8045, -58.1553
# Fetching data for coordinates: 18.5392, -72.335
# Fetching data for coordinates: 14.0818, -87.2068
# Fetching data for coordinates: 22.2783, 114.1747
# Fetching data for coordinates: 47.498, 19.0399
# Fetching data for coordinates: 64.1355, -21.8954
# Fetching data for coordinates: 28.6667, 77.2167
# Fetching data for coordinates: -6.2118, 106.8416
# Fetching data for coordinates: 35.6944, 51.4215
# Fetching data for coordinates: 33.3406, 44.4009
# Fetching data for coordinates: 53.3331, -6.2489
# Fetching data for coordinates: 54.15, -4.4833
# Fetching data for coordinates: 31.769, 35.2163
# Fetching data for coordinates: 41.8947, 12.4811
# Fetching data for coordinates: 6.8167, -5.2667
# Fetching data for coordinates: 17.997, -76.7936
# Fetching data for coordinates: 35.6895, 139.6917
# Fetching data for coordinates: 49.1833, -2.1
# Fetching data for coordinates: 31.9552, 35.945
# Fetching data for coordinates: 51.1801, 71.446
# Fetching data for coordinates: -1.2833, 36.8167
# Fetching data for coordinates: 1.3272, 172.9813
# Fetching data for coordinates: 29.3697, 47.9783
# Fetching data for coordinates: 42.87, 74.59
# Fetching data for coordinates: 17.9667, 102.6
# Fetching data for coordinates: 56.946, 24.1059
# Fetching data for coordinates: 33.9, 35.4833
# Fetching data for coordinates: -29.3167, 27.4833
# Fetching data for coordinates: 6.3005, -10.7969
# Fetching data for coordinates: 32.8752, 13.1875
# Fetching data for coordinates: 47.1415, 9.5215
# Fetching data for coordinates: 54.6892, 25.2798
# Fetching data for coordinates: 49.6117, 6.13
# Fetching data for coordinates: 42.0, 21.4333
# Fetching data for coordinates: -18.9137, 47.5361
# Fetching data for coordinates: -13.9669, 33.7873
# Fetching data for coordinates: 3.1412, 101.6865
# Fetching data for coordinates: 4.1748, 73.5089
# Fetching data for coordinates: 12.65, -8.0
# Fetching data for coordinates: 35.8997, 14.5147
# Fetching data for coordinates: 7.0897, 171.3803
# Fetching data for coordinates: 14.6089, -61.0733
# Fetching data for coordinates: 18.0858, -15.9785
# Fetching data for coordinates: -20.1619, 57.4989
# Fetching data for coordinates: -12.7794, 45.2272
# Fetching data for coordinates: 19.4273, -99.1419
# Fetching data for coordinates: 47.0056, 28.8575
# Fetching data for coordinates: 43.7333, 7.4167
# Fetching data for coordinates: 47.9077, 106.8832
# Fetching data for coordinates: 16.7918, -62.2106
# Fetching data for coordinates: 34.0133, -6.8326
# Fetching data for coordinates: -25.9653, 32.5892
# Fetching data for coordinates: -22.5594, 17.0832
# Fetching data for coordinates: -0.5308, 166.9112
# Fetching data for coordinates: 27.7017, 85.3206
# Fetching data for coordinates: 52.374, 4.8897
# Fetching data for coordinates: -22.2763, 166.4572
# Fetching data for coordinates: -41.2866, 174.7756
# Fetching data for coordinates: 12.1328, -86.2504
# Fetching data for coordinates: 13.5137, 2.1098
# Fetching data for coordinates: 9.0574, 7.4898
# Fetching data for coordinates: -19.0585, -169.9213
# Fetching data for coordinates: -29.0569, 167.9597
# Fetching data for coordinates: 39.0194, 125.7547
# Fetching data for coordinates: 15.2123, 145.7545
# Fetching data for coordinates: 59.9127, 10.7461
# Fetching data for coordinates: 23.6139, 58.5922
# Fetching data for coordinates: 33.7035, 73.0594
# Fetching data for coordinates: 7.3426, 134.4789
# Fetching data for coordinates: 8.9958, -79.5196
# Fetching data for coordinates: -9.4431, 147.1797
# Fetching data for coordinates: -25.3007, -57.6359
# Fetching data for coordinates: -12.0432, -77.0282
# Fetching data for coordinates: 14.6042, 120.9822
# Fetching data for coordinates: -25.0667, -130.1
# Fetching data for coordinates: 52.2298, 21.0118
# Fetching data for coordinates: 38.7169, -9.1399
# Fetching data for coordinates: 18.4663, -66.1057
# Fetching data for coordinates: 25.2747, 51.5245
# Fetching data for coordinates: -4.2592, 15.2847
# Fetching data for coordinates: 44.4328, 26.1043
# Fetching data for coordinates: 55.7558, 37.6173
# Fetching data for coordinates: -1.9474, 30.0579
# Fetching data for coordinates: -20.8823, 55.4504
# Fetching data for coordinates: -15.9387, -5.7168
# Fetching data for coordinates: 17.2948, -62.7261
# Fetching data for coordinates: 14.006, -60.991
# Fetching data for coordinates: 46.7738, -56.1815
# Fetching data for coordinates: 13.1587, -61.2248
# Fetching data for coordinates: -13.8333, -171.7667
# Fetching data for coordinates: 43.9333, 12.45
# Fetching data for coordinates: 24.6905, 46.7096
# Fetching data for coordinates: 14.6937, -17.4441
# Fetching data for coordinates: 44.8176, 20.4633
# Fetching data for coordinates: -4.6167, 55.45
# Fetching data for coordinates: 8.484, -13.2299
# Fetching data for coordinates: 1.2897, 103.8501
# Fetching data for coordinates: 48.1482, 17.1067
# Fetching data for coordinates: 46.0511, 14.5051
# Fetching data for coordinates: -9.4333, 159.95
# Fetching data for coordinates: 2.0416, 45.3435
# Fetching data for coordinates: -33.9258, 18.4232
# Fetching data for coordinates: -54.2833, -36.5
# Fetching data for coordinates: 37.5665, 126.978
# Fetching data for coordinates: 4.8517, 31.5825
# Fetching data for coordinates: 40.4165, -3.7026
# Fetching data for coordinates: 6.9319, 79.8478
# Fetching data for coordinates: 15.5518, 32.5324
# Fetching data for coordinates: 5.8664, -55.1668
# Fetching data for coordinates: 78.2333, 15.6333
# Fetching data for coordinates: -26.3167, 31.1333
# Fetching data for coordinates: 59.3326, 18.0649
# Fetching data for coordinates: 46.9481, 7.4474
# Fetching data for coordinates: 33.5, 36.3
# Fetching data for coordinates: 0.3333, 6.7333
# Fetching data for coordinates: 25.033, 121.5654
# Fetching data for coordinates: 38.5358, 68.7791
# Fetching data for coordinates: -6.8, 39.2833
# Fetching data for coordinates: 13.722, 100.5252
# Fetching data for coordinates: 25.0833, -77.35
# Fetching data for coordinates: 13.4531, -16.5775
# Fetching data for coordinates: 6.1375, 1.2123
# Fetching data for coordinates: -9.38, -171.25
# Fetching data for coordinates: -21.1394, -175.2032
# Fetching data for coordinates: 10.6662, -61.5166
# Fetching data for coordinates: 36.819, 10.1658
# Fetching data for coordinates: 39.9199, 32.8543
# Fetching data for coordinates: 37.95, 58.3833
# Fetching data for coordinates: -8.5189, 179.1991
# Fetching data for coordinates: 0.3163, 32.5822
# Fetching data for coordinates: 50.4454, 30.5186
# Fetching data for coordinates: 24.4648, 54.3618
# Fetching data for coordinates: 51.5085, -0.1257
# Fetching data for coordinates: 38.8951, -77.0364
# Fetching data for coordinates: -34.8335, -56.1674
# Fetching data for coordinates: 41.2647, 69.2163
# Fetching data for coordinates: -17.7338, 168.3219
# Fetching data for coordinates: 10.4806, -66.9036
# Fetching data for coordinates: 21.0285, 105.8542
# Fetching data for coordinates: -13.2833, -176.1667
# Fetching data for coordinates: 27.1532, -13.2014
# Fetching data for coordinates: 15.3531, 44.2078
# Fetching data for coordinates: -15.4134, 28.2771
# Fetching data for coordinates: -17.8294, 31.0539
#              date  avg_temp_c  precipitation_mm  avg_wind_speed_kmh  latitude  \
# 0      2023-08-20        27.3               0.0                 0.1   34.5289
# 1      2023-08-21        27.4               0.0                 0.2   34.5289
# 2      2023-08-22        28.0               0.0                 0.6   34.5289
# 3      2023-08-23        28.1               0.0                 0.8   34.5289
# 4      2023-08-24        26.8               0.0                 0.9   34.5289
# ...           ...         ...               ...                 ...       ...
# 69259  2024-06-22        13.6               0.0                11.1  -17.8294
# 69260  2024-06-23        13.7               0.0                14.1  -17.8294
# 69261  2024-06-24        13.5               0.0                14.8  -17.8294
# 69262  2024-06-25        13.6               0.0                13.2  -17.8294
# 69263  2024-06-26        13.0               0.0                13.1  -17.8294
#
#        longitude
# 0        69.1725
# 1        69.1725
# 2        69.1725
# 3        69.1725
# 4        69.1725
# ...          ...
# 69259    31.0539
# 69260    31.0539
# 69261    31.0539
# 69262    31.0539
# 69263    31.0539
#
# [69264 rows x 6 columns]

# %%
#add countries and capitals to new weather data 
coord_pairs = merged_df[['country','capital','latitude', 'longitude']].drop_duplicates().values

# Convert coord_pairs to a DataFrame
coord_df = pd.DataFrame(coord_pairs, columns=['country', 'capital', 'latitude', 'longitude'])
df_with_countries = combined_df.merge(coord_df, on=['latitude', 'longitude'], how='left')

#combine both weather datasets
full_weather_df = pd.concat([merged_df,df_with_countries],ignore_index=True)
#save weather to csv
full_weather_df.to_csv('Data/historical_weather_data.csv', index=False)
full_weather_df.tail()
# Out:
#           country capital        date  avg_temp_c  precipitation_mm  \
# 5071710  Zimbabwe  Harare  2024-06-22        13.6               0.0
# 5071711  Zimbabwe  Harare  2024-06-23        13.7               0.0
# 5071712  Zimbabwe  Harare  2024-06-24        13.5               0.0
# 5071713  Zimbabwe  Harare  2024-06-25        13.6               0.0
# 5071714  Zimbabwe  Harare  2024-06-26        13.0               0.0
#
#          avg_wind_speed_kmh latitude longitude
# 5071710                11.1 -17.8294   31.0539
# 5071711                14.1 -17.8294   31.0539
# 5071712                14.8 -17.8294   31.0539
# 5071713                13.2 -17.8294   31.0539
# 5071714                13.1 -17.8294   31.0539

# %% [markdown]
# ##### Set up daily api calls

# %%
## get daily weather data for capital cities
## additional data for each place: Air quality, Water Quality, Temperature 
## set up api daily connection

# 230 calls daily  for weather 
#url = f'https://api.open-meteo.com/v1/forecast?latitude=52.52&longitude=13.41'

#url = f'https://api.openweathermap.org/data/2.5/weather?q={cityname}&appid={API key}'

latitudes = merged_df['latitude'].unique()
longitudes = merged_df['longitude'].unique()

# Convert float values to strings and join them with commas
lat_string = ",".join(map(str, latitudes))
long_string = ",".join(map(str, longitudes))

#precipitation_mm	avg_wind_speed_kmh	avg_sea_level_pres_hpa

#https://api.open-meteo.com/v1/forecast?latitude=52.52&longitude=13.41
url = f'https://api.open-meteo.com/v1/forecast?latitude={lat_string}&longitude={long_string}&start_date=2024-06-27&end_date=2024-06-27&daily=temperature_2m_max,temperature_2m_min,precipitation_sum,wind_speed_10m_max'
#url = 'https://api.open-meteo.com/v1/forecast?latitude=52.52,51.5085&longitude=13.41,-0.1257&hourly=temperature_2m'

#headers = { 'X-Auth-Token': api_key }

response = requests.get(url)

#print(response) #response code 200: Good 400: Bad
jsonRes = response.json()
#print(jsonRes)

# %%
rows = []

for location in jsonRes:
    lat = location['latitude']
    lon = location['longitude']
    times = location['daily']['time']
    max_temps = location['daily']['temperature_2m_max']
    min_temps = location['daily']['temperature_2m_min']
    
    for date, max_temp, min_temp in zip(times, max_temps, min_temps):
        # Calculate average temperature if both max and min are available
        if max_temp is not None and min_temp is not None:
            avg_temp = mean([max_temp, min_temp])          
        else:
            avg_temp = None
        
        rows.append({
            'date': date,
            'avg_temp_c': avg_temp,
            'latitude': lat,
            'longitude': lon
        })

testerweatherapi = pd.DataFrame(rows)
testerweatherapi
# Out:
#            date  avg_temp_c  latitude   longitude
# 0    2024-06-27       26.20   34.6250   69.125000
# 1    2024-06-27       22.20   41.3125   19.812500
# 2    2024-06-27       24.70   36.7500    3.062500
# 3    2024-06-27       26.60  -14.2500 -170.750000
# 4    2024-06-27       23.65   -8.8750   13.250000
# ..          ...         ...       ...         ...
# 225  2024-06-27       27.90  -13.2500 -176.125000
# 226  2024-06-27       22.15   27.2000  -13.199999
# 227  2024-06-27       24.40   15.3750   44.250000
# 228  2024-06-27       15.80  -15.3750   28.250000
# 229  2024-06-27       14.50  -17.8750   31.000000
#
# [230 rows x 4 columns]

# %% [markdown]
# #### Earthquakes

# %% [markdown]
# ##### Set up DB Data

# %%
# populate db with historical data first
earthquake_data=pd.read_csv('Data/Significant_Earthquakes.csv') #+5.0 mag
#manipulate to only have capital cites
earthquake_data = earthquake_data[['time', 'latitude', 'longitude', 'mag', 'magType', 'place','type']]
earthquake_data = earthquake_data[earthquake_data['type'] == 'earthquake']
earthquake_data = earthquake_data.drop(columns=['type'])

#change time format
earthquake_data['time'] = pd.to_datetime(earthquake_data['time']) 

earthquake_data
# Out:
#                        time  latitude  longitude   mag magType  \
# 0 1900-10-09 12:25:00+00:00     57.09    -153.48  7.86      mw
# 1 1901-03-03 07:45:00+00:00     36.00    -120.50  6.40      ms
# 2 1901-07-26 22:20:00+00:00     40.80    -115.70  5.00      fa
# 3 1901-12-30 22:34:00+00:00     52.00    -160.00  7.00      ms
# 4 1902-01-01 05:20:30+00:00     52.38    -167.45  7.00      ms
#
#                                 place
# 0      16 km SW of Old Harbor, Alaska
# 1  12 km NNW of Parkfield, California
# 2             6 km SE of Elko, Nevada
# 3                     south of Alaska
# 4      113 km ESE of Nikolski, Alaska

# %%
## get historical data of earthquakes
## set up api daily connection

#get earthquakes from 2024-05-25+

#https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2014-01-01&endtime=2014-01-02
#url = f'https://earthquake.usgs.gov/fdsnws/event/1/[METHOD[?PARAMETERS]]'
url = f'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2024-05-25&endtime=2024-06-27&minmagnitude=5'

#headers = { 'X-Auth-Token': api_key }

response = requests.get(url)

#print(response) #response code 200: Good 400: Bad
jsonRes = response.json()

#collect data
extra_earthquake_list = []
for earthquake in jsonRes['features']:
        data = {
            'time': earthquake['properties']['time'],
            'latitude': earthquake['geometry']['coordinates'][1],
            'longitude': earthquake['geometry']['coordinates'][0],
            'mag': earthquake['properties']['mag'],
            'magType': earthquake['properties']['magType'],
            'place': earthquake['properties']['place']
        }  
        extra_earthquake_list.append(data)
    
extra_earthquake_df = pd.DataFrame(extra_earthquake_list)
extra_earthquake_df['time'] = pd.to_datetime(extra_earthquake_df['time'], unit='ms',origin='unix', utc=True) 
extra_earthquake_df[:] = extra_earthquake_df[::-1]
extra_earthquake_df

#append to all earthquakes dataset
full_earthquake_df = pd.concat([earthquake_data,extra_earthquake_df],ignore_index=True)
full_earthquake_df.to_csv('Data/historical_earthquake_data.csv', index=False)
full_earthquake_df
# Out:
#                                    time  latitude  longitude   mag magType  \
# 0             1900-10-09 12:25:00+00:00   57.0900  -153.4800  7.86      mw
# 1             1901-03-03 07:45:00+00:00   36.0000  -120.5000  6.40      ms
# 2             1901-07-26 22:20:00+00:00   40.8000  -115.7000  5.00      fa
# 3             1901-12-30 22:34:00+00:00   52.0000  -160.0000  7.00      ms
# 4             1902-01-01 05:20:30+00:00   52.3800  -167.4500  7.00      ms
# ...                                 ...       ...        ...   ...     ...
# 102161 2024-06-25 06:45:33.808000+00:00  -20.9050  -173.8305  5.10      mb
# 102162 2024-06-25 08:20:46.696000+00:00  -54.2645   -56.9279  5.00      mb
# 102163 2024-06-25 08:30:59.282000+00:00   33.4887   141.2838  5.40     mww
# 102164 2024-06-26 01:24:13.670000+00:00    8.0754    90.4097  5.60     mww
# 102165 2024-06-26 12:57:50.835000+00:00  -13.2540   167.0970  5.10     mww
#
#                                      place
# 0           16 km SW of Old Harbor, Alaska
# 1       12 km NNW of Parkfield, California
# 2                  6 km SE of Elko, Nevada
# 3                          south of Alaska
# 4           113 km ESE of Nikolski, Alaska
# ...                                    ...
# 102161        126 km ENE of ‘Ohonua, Tonga
# 102162             Falkland Islands region
# 102163       204 km SSE of Katsuura, Japan
# 102164       Nicobar Islands, India region
# 102165           84 km NW of Sola, Vanuatu
#
# [102166 rows x 6 columns]

# %% [markdown]
# ##### Set up daily api calls

# %%
todaysDate = '2024-05-25'
url = f'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={todaysDate}&endtime={todaysDate}&minmagnitude=5'

#headers = { 'X-Auth-Token': api_key }

response = requests.get(url)

#print(response) #response code 200: Good 400: Bad
jsonRes = response.json()

# %% [markdown]
# #### Air Quality

# %%
url = f'https://aqicn.org/api'

# %% [markdown]
# #### Natural disasters

# %%
#url = f'https://eonet.gsfc.nasa.gov/api/v2.1/events?days=20'
url = f'https://eonet.gsfc.nasa.gov/api/v2.1/events'

#headers = { 'X-Auth-Token': api_key }

response = requests.get(url)

#print(response) #response code 200: Good 400: Bad
jsonRes = response.json()
print(jsonRes);
# Out:
# {'title': 'EONET Events', 'description': 'Natural events from EONET.', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events', 'events': [{'id': 'EONET_8212', 'title': '0289 NE DARLENE 3 Wildfire, Deschutes, Oregon', 'description': 'One Mile South Southeast of the city of La Pine, Oregon', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events/EONET_8212', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'IRWIN', 'url': 'https://irwin.doi.gov/observer/'}], 'geometries': [{'date': '2024-06-25T16:15:00Z', 'type': 'Point', 'coordinates': [-121.413517, 44.267745]}]}, {'id': 'EONET_8225', 'title': 'APACHE Wildfire, Butte, California', 'description': 'Palermo, South of Oroville', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events/EONET_8225', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'IRWIN', 'url': 'https://irwin.doi.gov/observer/'}], 'geometries': [{'date': '2024-06-24T22:21:00Z', 'type': 'Point', 'coordinates': [-121.482631, 39.418598]}]}, {'id': 'EONET_8260', 'title': 'Wildfire in Canada 1019923', 'description': '', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events/EONET_8260', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'GDACS', 'url': 'https://www.gdacs.org/report.aspx?eventtype=WF&amp;eventid=1019923'}], 'geometries': [{'date': '2024-06-24T19:00:00Z', 'type': 'Point', 'coordinates': [-64.11572465175655, 51.79184131660541]}]}, {'id': 'EONET_8236', 'title': 'BOLT Wildfire, Fresno, California', 'description': '', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events/EONET_8236', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'IRWIN', 'url': 'https://irwin.doi.gov/observer/'}], 'geometries': [{'date': '2024-06-24T18:01:00Z', 'type': 'Point', 'coordinates': [-119.308956, 36.79027]}]}, {'id': 'EONET_8229', 'title': '0277 RV LONG BEND Wildfire, Wasco, Oregon', 'description': '2 SW of Maupin, OR', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events/EONET_8229', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'IRWIN', 'url': 'https://irwin.doi.gov/observer/'}], 'geometries': [{'date': '2024-06-22T20:03:00Z', 'type': 'Point', 'coordinates': [-121.131392, 45.126083]}]}, {'id': 'EONET_8214', 'title': 'Naluk Wildfire, Northwest Arctic, Alaska', 'description': '6 Miles SE of Hockley Hills', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events/EONET_8214', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'IRWIN', 'url': 'https://irwin.doi.gov/observer/'}], 'geometries': [{'date': '2024-06-21T23:28:00Z', 'type': 'Point', 'coordinates': [-159.506833, 66.8905]}]}, {'id': 'EONET_8226', 'title': 'Crater Mountain Wildfire, Yukon-Koyukuk, Alaska', 'description': '17 miles west of Takotna, AK.', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events/EONET_8226', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'IRWIN', 'url': 'https://irwin.doi.gov/observer/'}], 'geometries': [{'date': '2024-06-21T22:48:00Z', 'type': 'Point', 'coordinates': [-156.425, 63.1]}]}, {'id': 'EONET_8223', 'title': 'Clear Wildfire, Fairbanks North Star, Alaska', 'description': '17 miles west of Salcha', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events/EONET_8223', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'IRWIN', 'url': 'https://irwin.doi.gov/observer/'}], 'geometries': [{'date': '2024-06-21T21:42:00Z', 'type': 'Point', 'coordinates': [-147.5935, 64.590783]}]}, {'id': 'EONET_8164', 'title': 'Wildfire in Brazil 1019880', 'description': '', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events/EONET_8164', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'GDACS', 'url': 'https://www.gdacs.org/report.aspx?eventtype=WF&amp;eventid=1019880'}], 'geometries': [{'date': '2024-06-21T19:00:00Z', 'type': 'Point', 'coordinates': [-57.2659958049615, -19.418036795163513]}]}, {'id': 'EONET_8165', 'title': 'Wildfire in Paraguay 1019879', 'description': '', 'link': 'https://eonet.gsfc.nasa.gov/ap ...

# %% [markdown]
# ### Space

# %% [markdown]
# #### Nasa Picture of the Day

# %%
#url = f'https://api.nasa.gov/neo/rest/v1/neo/3542519?api_key={NASA_api_key}'
url = f'https://api.nasa.gov/planetary/apod?api_key={NASA_api_key}'

#headers = { 'X-Auth-Token': api_key }

response = requests.get(url)

#print(response) #response code 200: Good 400: Bad
jsonRes = response.json()
print(jsonRes)
# Out:
# {'copyright': '\nJeff Dai\n(TWAN); \nMusic \n(License): \nSuite bergamasque by \nClaude Debussy\n', 'date': '2024-06-26', 'explanation': "What's happening in the sky this unusual night? Most striking in the featured 4.5-hour 360-degree panoramic video, perhaps, is the pink and purple aurora. That's because this night, encompassing May 11, was famous for its auroral skies around the world. As the night progresses, auroral bands shimmer, the central band of our Milky Way Galaxy rises, and stars shift as the Earth rotates beneath them.  Captured here simultaneously is a rare red band running above the aurora: a SAR arc, seen to change only slightly. The flashing below the horizon is caused by passing cars, while the moving spots in the sky are satellites and airplanes.  The featured video was captured from Xinjiang, China with four separate cameras.", 'media_type': 'video', 'service_version': 'v1', 'title': 'Timelapse: Aurora, SAR, and the Milky Way', 'url': 'https://www.youtube.com/embed/fisAZYNwDgk?rel=0'}

# %% [markdown]
# #### Asteroids nearby

# %%
#url = f'https://api.nasa.gov/neo/rest/v1/neo/3542519?api_key={NASA_api_key}'
#url = f'https://api.nasa.gov/neo/rest/v1/neo/browse?api_key={NASA_api_key}'
#current date astroid is closest to earth
url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date=2024-06-26&end_date=2024-06-26&api_key={NASA_api_key}'
#headers = { 'X-Auth-Token': api_key }

response = requests.get(url)

#print(response) #response code 200: Good 400: Bad
neoJSON = response.json()
#print(neoJSON)

# %%
miss_miles = [x['close_approach_data'][0]['miss_distance']['miles'] for x in neoJSON["near_earth_objects"]['2024-06-26']]
diameter_miles = [x['estimated_diameter']['miles']['estimated_diameter_max'] for x in neoJSON["near_earth_objects"]['2024-06-26']]
is_hazardous = [x['is_potentially_hazardous_asteroid'] for x in neoJSON["near_earth_objects"]['2024-06-26']]
print(miss_miles)
print(diameter_miles)
print(is_hazardous)
# Out:
# ['30082164.1062733288', '41823340.5999610626', '28544496.757910679', '44150778.4165702704', '41308947.096381527', '8913021.305752321', '10215776.5137473234']
# [0.3085964738, 0.0771597762, 0.0029880713, 0.0139120445, 0.037272709, 0.0100783853, 0.1774152548]
# [False, False, False, False, False, False, False]

# %% [markdown]
# ### Connect to DB

# %%
#get secrets from .env
load_dotenv()

username = os.getenv('sql_user')
password = os.getenv('sql_pass')
host = os.getenv('host')

conn = psql.connect(database = 'pagila', 
                    user = username, 
                    host = host, 
                    password = password, 
                    port = 5432)

cur = conn.cursor()
SQL = """
CREATE TABLE IF NOT EXISTS student.mytable (

  my_id serial primary key,
  my_str varchar(50)
)
"""


cur.execute(SQL)
conn.commit()
